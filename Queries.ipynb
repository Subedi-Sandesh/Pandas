# %%
import pandas as pd

# %%
df = pd.read_csv("Welcome program.csv")
df.set_index("IOE roll no:", inplace = True)
df.sort_index(inplace = True)

# %%
df
# Out:
#               Unnamed: 0                    Username             Name:  \
# IOE roll no:
# PAS081BCT001         NaN       sahaanand59@gmail.com  Aanand Kumar Sah
# PAS081BCT005         NaN       rizalaryan2@gmail.com       Adip Rijal
# PAS081BCT007         NaN    prince12poudel@gmail.com      Anjal Poudel
# PAS081BCT010         NaN  acharyaanuska111@gmail.com   Anuska Acharya
# PAS081BCT020         NaN      manojpoudelp@gmail.com    Meghraj Poudel
# PAS081BCT023         NaN    khanalpragya10@gmail.com    Pragya khanal
# PAS081BCT024         NaN   prakatsharma064@gmail.com     Prakat Sharma
# PAS081BCT026         NaN   pranjaljoshi095@gmail.com     Pranjal Joshi
# NaN                  NaN                         NaN               NaN
# NaN                  NaN                         NaN               NaN
# NaN                  NaN                         NaN               NaN
#
#               Phone number: Preference:
# IOE roll no:
# PAS081BCT001   9.826361e+09         Veg
# ...

# %%
# identifying group veg and non veg student names
print(df.loc[df["Preference:"] == "Veg"])
print(df.loc[df["Preference:"] == "Non-Veg"])
# Out:
#               Unnamed: 0                    Username             Name:  \
# IOE roll no:
# PAS081BCT001         NaN       sahaanand59@gmail.com  Aanand Kumar Sah
# PAS081BCT005         NaN       rizalaryan2@gmail.com       Adip Rijal
# PAS081BCT010         NaN  acharyaanuska111@gmail.com   Anuska Acharya
# PAS081BCT026         NaN   pranjaljoshi095@gmail.com     Pranjal Joshi
#
#               Phone number: Preference:
# IOE roll no:
# PAS081BCT001   9.826361e+09         Veg
# PAS081BCT005   9.804456e+09         Veg
# PAS081BCT010   9.769211e+09         Veg
# PAS081BCT026   9.868553e+09         Veg
#               Unnamed: 0                   Username           Name:  \
# IOE roll no:
# PAS081BCT007         NaN   prince12poudel@gmail.com    Anjal Poudel
# PAS081BCT020         NaN     manojpoudelp@gmail.com  Meghraj Poudel
# PAS081BCT023         NaN   khanalpragya10@gmail.com  Pragya khanal
# PAS081BCT024         NaN  prakatsharma064@gmail.com   Prakat Sharma
#
# ...
